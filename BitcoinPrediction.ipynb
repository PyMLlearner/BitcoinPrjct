# %% [markdown]
# # Bitcoin Price Predictor

# %% [markdown]
#   The bitcoin price predictor is a useful project. The blockchain technology is increasing and there are many digital currencies rising. This project will help us predict the price of the bitcoin using previous data.

# %% [markdown]
# ## Importing the Libraries

# %%
# for basic operations
import numpy as np
import pandas as pd

# for data visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# for interactive analysis
import ipywidgets
from ipywidgets import interact
from ipywidgets import interact_manual

# for time series analysis
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA

# %% [markdown]
# ## Reading the Data

# %%
# lets import the dataset
data = pd.read_csv('bitcoin.csv')

# lets check the shape of the dataset
data.shape
# Out:
# (1877, 7)

# %%
# lets check the columns in the dataset
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
# lets check the head of the dataset
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  359.546204  361.468506  351.586884  355.957367  355.957367
# 1  2014-09-18  355.588409  355.505402  319.789459  328.539368  328.539368
# 2  2014-09-19  328.278503  330.936707  298.921021  307.761139  307.761139
# 3  2014-09-20  307.665253  329.978180  303.931244  318.758972  318.758972
# 4  2014-09-21  318.120514  321.504517  306.502197  310.632446  310.632446
#
#      Volume
# 0  16389165
# 1  26691849
# 2  29560102
# 3  28736825
# 4  20702624

# %%
# lets check the tail of the dataset
data.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 1872  2019-11-02  8291.172852  8397.126953  8282.598633  8349.874023
# 1873  2019-11-03  8349.936523  8399.804688  8186.173828  8270.445313
# 1874  2019-11-04  8270.670898  8541.590820  8259.809570  8458.521484
# 1875  2019-11-05  8458.875000  8540.323242  8359.278320  8436.573242
# 1876  2019-11-06  8435.071289  8512.726563  8406.735352  8456.394531
#
#         Adj Close       Volume
# 1872  8349.874023  19021882025
# 1873  8270.445313  18924326413
# 1874  8458.521484  23517560012
# 1875  8436.573242  23658103729
# 1876  8456.394531  20898606220

# %%
# lets check the summary of the dataset
data.sample(5)
# Out:
#             Date         Open         High          Low        Close  \
# 1339  2018-05-18  6863.881836  7028.047363  6755.459473  7007.192871
# 1463  2018-09-19  5456.752441  5523.306152  5319.002930  5481.957031
# 265   2015-06-09   202.640533   204.402161   201.546555   202.840958
# 1599  2019-02-02  3041.350098  3075.093506  3026.468018  3073.150146
# 1622  2019-02-25  3356.702637  3446.437988  3357.589600  3416.384521
#
#         Adj Close      Volume
# 1339  7007.192871  4895278308
# 1463  5481.957031  3796555860
# 265    202.840958    25109015
# 1599  3073.150146  4426467434
# 1622  3416.384521  8199608659

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# In statistics,Exploratory Analysis(EDA)is an approach to analyzing data sets to summarize their main characteristics,often with visual methods.
#
#  A statistical model can be used or not, but primarily EDA is for seeing what the data can tell us beyond the formal modeling or hypothesis testing task.

# %%
# lets check the information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1877 entries, 0 to 1876
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1877 non-null   object
#  1   Open       1877 non-null   float64
#  2   High       1877 non-null   float64
#  3   Low        1877 non-null   float64
#  4   Close      1877 non-null   float64
#  5   Adj Close  1877 non-null   float64
#  6   Volume     1877 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 102.8+ KB

# %%
# lets check the data types of the data
data.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
# lets check the null values if present in the data
data.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ## Inferential Statistics

# %% [markdown]
# Descriptive statistics describes data (for example, a chart or graph) and inferential statistics allows we to make predictions (“inferences”) from that data. With inferential statistics, we take data from samples and make generalizations about a population.

# %%
# lets check basic statistics
x = data.describe()
x.style.bar()
# Out:
# <style  type="text/css" >
#     #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.5%, transparent 10.5%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.0%, transparent 10.0%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.8%, transparent 10.8%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.5%, transparent 10.5%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.5%, transparent 10.5%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row0_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.3%, transparent 18.3%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.1%, transparent 18.1%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.2%, transparent 18.2%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.3%, transparent 18.3%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.3%, transparent 18.3%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.4%, transparent 9.4%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.7%, transparent 19.7%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.6%, transparent 19.6%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.4%, transparent 19.4%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.7%, transparent 19.7%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.7%, transparent 19.7%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.9%, transparent 14.9%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row3_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row3_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row3_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row3_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row3_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 1.1%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.0%, transparent 6.0%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.8%, transparent 5.8%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.1%, transparent 6.1%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.1%, transparent 6.1%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.1%, transparent 6.1%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.9%, transparent 0.9%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.6%, transparent 33.6%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.9%, transparent 32.9%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.9%, transparent 33.9%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.5%, transparent 33.5%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.5%, transparent 33.5%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row6_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.8%, transparent 11.8%);
#         }    #T_99ed45ca_c775_11ea_94a7_d0c5d33d8e56row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  lin

# %%
# lets check the correlation
x = data.corr()
x.style.bar(color = ['silver'], align = 'mid')
# Out:
# <style  type="text/css" >
#     #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 100.0%, transparent 100.0%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.9%, transparent 99.9%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.8%, transparent 99.8%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.8%, transparent 99.8%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.8%, transparent 99.8%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 78.3%, transparent 78.3%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.9%, transparent 99.9%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 100.0%, transparent 100.0%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.8%, transparent 99.8%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.9%, transparent 99.9%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.9%, transparent 99.9%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 78.6%, transparent 78.6%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.8%, transparent 99.8%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.8%, transparent 99.8%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 100.0%, transparent 100.0%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.9%, transparent 99.9%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.9%, transparent 99.9%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 78.4%, transparent 78.4%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.8%, transparent 99.8%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.9%, transparent 99.9%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.9%, transparent 99.9%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 100.0%, transparent 100.0%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 100.0%, transparent 100.0%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 78.5%, transparent 78.5%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.8%, transparent 99.8%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.9%, transparent 99.9%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.9%, transparent 99.9%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 100.0%, transparent 100.0%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 100.0%, transparent 100.0%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 78.5%, transparent 78.5%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 78.3%, transparent 78.3%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 78.6%, transparent 78.6%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 78.4%, transparent 78.4%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 78.5%, transparent 78.5%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 78.5%, transparent 78.5%);
#         }    #T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 100.0%, transparent 100.0%);
#         }</style><table id="T_9a118e8c_c775_11ea_9392_d0c5d33d8e56" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Open</th>        <th class="col_heading level0 col1" >High</th>        <th class="col_heading level0 col2" >Low</th>        <th class="col_heading level0 col3" >Close</th>        <th class="col_heading level0 col4" >Adj Close</th>        <th class="col_heading level0 col5" >Volume</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9a118e8c_c775_11ea_9392_d0c5d33d8e56level0_row0" class="row_heading level0 row0" >Open</th>
#                         <td id="T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_9a118e8c_c775_11ea_9392_d0c5d33d8e56row0_col1" class="data r

# %%
# lets check the covariance of the data
x = data.cov()
x.style.bar(color = 'gold', align = 'mid')
# Out:
# <style  type="text/css" >
#     #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }    #T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }</style><table id="T_9bce593e_c775_11ea_8e36_d0c5d33d8e56" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Open</th>        <th class="col_heading level0 col1" >High</th>        <th class="col_heading level0 col2" >Low</th>        <th class="col_heading level0 col3" >Close</th>        <th class="col_heading level0 col4" >Adj Close</th>        <th class="col_heading level0 col5" >Volume</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9bce593e_c775_11ea_8e36_d0c5d33d8e56level0_row0" class="row_heading level0 row0" >Open</th>
#                         <td id="T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row0_col0" class="data row0 col0" >11475741.690472</td>
#                         <td id="T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row0_col1" class="data row0 col1" >11842264.166148</td>
#                         <td id="T_9bce593e_c775_11ea_8e36_d0c5d33d8e56row0_col2" class="data row0

# %%
# lets check the pairplot of the data
sns.pairplot(data)
plt.show()

# %% [markdown]
# ## Financial Analytics

# %% [markdown]
# Financial analytics is the creation of ad hoc analysis to answer specific business questions and forecast possible future financial scenarios.
#
# The goal of financial analytics is to shape the strategy for business through reliable, factual insight rather than intuition.

# %%
# lets convert the date variable into a datetime object
data['Date'] = pd.to_datetime(data['Date'])

# lets check the datatype of the date column now
data.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
# lets do some plotting

plt.rcParams['figure.figsize'] = (14, 7)
plt.style.use('fivethirtyeight')

sns.lineplot(data['Date'], data['Open'])
plt.title('Time Series Analysis for Opening Values of Bitcoin', fontsize = 20)
plt.xlabel('Date')
plt.grid()
plt.ylabel('Opening Values for Bitcoin Market')
plt.show()

# %%
# lets do some plotting

plt.rcParams['figure.figsize'] = (14, 7)
plt.style.use('fivethirtyeight')

sns.lineplot(data['Date'],
             data['Close'],
             color = 'black')
plt.title('Time Series Analysis for Closing Values of Bitcoin', fontsize = 20)
plt.xlabel('Date')
plt.grid()
plt.ylabel('Closing Values for Bitcoin Market')
plt.show()

# %%
# lets do some plotting

plt.rcParams['figure.figsize'] = (14, 7)
plt.style.use('fivethirtyeight')

sns.lineplot(data['Date'],
             data['High'],
             color = 'red')
plt.title('Time Series Analysis for Highest Values of Bitcoin', fontsize = 20)
plt.xlabel('Date')
plt.grid()
plt.ylabel('Highest Values for Bitcoin Market')
plt.show()

# %%
# lets do some plotting

plt.rcParams['figure.figsize'] = (14, 7)
plt.style.use('fivethirtyeight')

sns.lineplot(data['Date'],
             data['Low'],
             color = 'green')
plt.title('Time Series Analysis for Lowest Values of Bitcoin', fontsize = 20)
plt.xlabel('Date')
plt.grid()
plt.ylabel('Lowest Values for Bitcoin Market')
plt.show()

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Daily Lag

# %% [markdown]
# First, we will create the column ‘daily lag’ which is basically just shifting the ‘Close’ price by one day back.

# %%
# (Note: there are often various metrics we can use but i am choosing ‘Close’ for convenience)
data['Daily Lag'] = data['Close'].shift(1)
data.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-17  359.546204  361.468506  351.586884  355.957367  355.957367
# 1 2014-09-18  355.588409  355.505402  319.789459  328.539368  328.539368
# 2 2014-09-19  328.278503  330.936707  298.921021  307.761139  307.761139
# 3 2014-09-20  307.665253  329.978180  303.931244  318.758972  318.758972
# 4 2014-09-21  318.120514  321.504517  306.502197  310.632446  310.632446
#
#      Volume   Daily Lag
# 0  16389165         NaN
# 1  26691849  355.957367
# 2  29560102  328.539368
# 3  28736825  307.761139
# 4  20702624  318.758972

# %% [markdown]
# ### Daily Returns

# %% [markdown]
# Daily returns tells us the returns that we obtain in a day after the stock price closes.

# %%
# lets make a column called Daily Returns

data['Daily Returns'] = (data['Daily Lag']/data['Close']) -1
data.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-17  359.546204  361.468506  351.586884  355.957367  355.957367
# 1 2014-09-18  355.588409  355.505402  319.789459  328.539368  328.539368
# 2 2014-09-19  328.278503  330.936707  298.921021  307.761139  307.761139
# 3 2014-09-20  307.665253  329.978180  303.931244  318.758972  318.758972
# 4 2014-09-21  318.120514  321.504517  306.502197  310.632446  310.632446
#
#      Volume   Daily Lag  Daily Returns
# 0  16389165         NaN            NaN
# 1  26691849  355.957367       0.083454
# 2  29560102  328.539368       0.067514
# 3  28736825  307.761139      -0.034502
# 4  20702624  318.758972       0.026161

# %% [markdown]
# ## Checking Distributions

# %% [markdown]
# A simple and commonly used plot to quickly check the distribution of a sample of data is the histogram. In the histogram, the data is divided into a pre-specified number of groups called bins.
#
# The data is then sorted into each bin and the count of the number of observations in each bin is retained.

# %% [markdown]
# ### Distribution Graph of Daily Lag

# %%
# lets check the Distribution of Daily Lag

plt.rcParams['figure.figsize'] = (15, 8)
plt.style.use('fivethirtyeight')

sns.distplot(data['Daily Lag'],
             color = 'black')
plt.title('Distribution of Daily Lag', fontsize = 20)
plt.show()

# %% [markdown]
# ### Distribution Graph of Daily Returns

# %%
# lets check the Distribution of Daily Lag

plt.rcParams['figure.figsize'] = (15, 8)
plt.style.use('fivethirtyeight')

sns.distplot(data['Daily Returns'],
             color = 'red')
plt.title('Distribution of Daily Returns', fontsize = 20)
plt.show()

# %% [markdown]
# ### Distribution Graph of Volume

# %%
# lets check the Distribution of Volume

plt.rcParams['figure.figsize'] = (15, 8)
plt.style.use('fivethirtyeight')

sns.distplot(data['Volume'],
             color = 'green')
plt.title('Distribution of Volume', fontsize = 20)
plt.show()

# %% [markdown]
# ### Statistics of Daily Lag And Daily Returns

# %%
# lets check the Statistics of Daily Lag and Daily Returns

mean = data['Daily Returns'].mean()
std = data['Daily Returns'].std()
print('Mean for Daily Returns :', mean)
print('Standard Deviation for Daily Returns :', std)
mean_lag = data['Daily Returns'].mean()
std_lag = data['Daily Returns'].std()
print('Mean for Daily Lag :', mean_lag)
print('Standard Deviation for Daily Lag :', std_lag)
# Out:
# Mean for Daily Returns : -0.0009202219778351076
# Standard Deviation for Daily Returns : 0.03941675903822447
# Mean for Daily Lag : -0.0009202219778351076
# Standard Deviation for Daily Lag : 0.03941675903822447

# %% [markdown]
# ### Graph of Buy and Sell Signals

# %%
# Generally returns are negative but we have to remember that this only considers the returns on a day-to-day basis 
# and so it just tells us that in general the return if we buy and sell on the same day, we will make a loss.

sns.distplot(data['Daily Returns'],
              color = 'black')
plt.axvline(mean,color='red',linestyle='dashed',linewidth=2)

#to plot the std line we plot both the positive and negative values 
plt.axvline(std,color='g',linestyle='dashed',linewidth=2)
plt.axvline(-std,color='g',linestyle='dashed',linewidth=2)
plt.title('Buy and Sell Signals based on the Bitcoin Data', fontsize = 20)
plt.show()

# %% [markdown]
# ### Kurtosis Values

# %% [markdown]
# Kurtosis tells us the ‘fatness’ of the tail and it is important because it tells us how ‘extreme’ can the values get.

# %%
# lets check the Kurtosis Values

print("Kurtosis Values for Daily Lags : ", data['Daily Lag'].kurtosis())
print("Kurtosis Values for Daily Returns :", data['Daily Returns'].kurtosis())
# Out:
# Kurtosis Values for Daily Lags :  0.2888694715340234
# Kurtosis Values for Daily Returns : 5.770034068011833

# %% [markdown]
# ### Time Series Analysis with ARIMA

# %% [markdown]
# AutoRegressive Integrated Moving Average abbreviated as ARIMA,is a Statical Analysis model that uses time series data to either better understand the data set or to predict future trends

# %%
# lets import the data 

test = pd.read_csv('Test.csv', index_col = 'Date')
train = pd.read_csv('Training.csv', index_col = 'Date')

# lets check the shape of the dataset
print("Shape of Test Dataset :", test.shape)
print("Shape of Train Dataset :", train.shape)
# Out:
# Shape of Test Dataset : (7, 6)
# Shape of Train Dataset : (1556, 6)

# %%
# lets check the head of the training dataset

train = train.sort_index()
train.index = pd.to_datetime(train.index)
train.head()
# Out:
#                Open     High      Low    Close       Volume      Market Cap
# Date
# 2014-04-01   457.00   495.34   457.00   478.38   35,685,800   5,752,280,000
# 2015-04-01   244.22   247.54   241.16   247.27   22,877,200   3,420,100,000
# 2016-04-01   416.76   418.17   415.83   417.96   51,235,700   6,409,540,000
# 2017-04-01  1071.71  1091.72  1061.09  1080.50  289,634,000  17,413,000,000
# 2014-04-02   479.14   495.05   431.27   437.14   49,647,600   6,032,970,000

# %%
# lets check the head of the testing dataset

test = test.sort_index()
test.index = pd.to_datetime(test.index)
test.head()
# Out:
#                Open     High      Low    Close         Volume      Market Cap
# Date
# 2017-08-01  2871.30  2921.35  2685.61  2718.26  1,324,670,000  47,321,800,000
# 2017-08-02  2727.13  2762.53  2668.59  2710.67  1,094,950,000  44,950,800,000
# 2017-08-03  2709.56  2813.31  2685.14  2804.73    804,797,000  44,666,400,000
# 2017-08-04  2806.93  2899.33  2743.72  2895.89  1,002,120,000  46,276,200,000
# 2017-08-05  2897.63  3290.01  2874.83  3252.91  1,945,700,000  47,778,200,000

# %%
# preparing the data

train = train['Close']
train.head()
# Out:
# Date
# 2014-04-01     478.38
# 2015-04-01     247.27
# 2016-04-01     417.96
# 2017-04-01    1080.50
# 2014-04-02     437.14
# Name: Close, dtype: float64

# %% [markdown]
# ### Analyzing Bitcoin Prices on Daily Bases

# %%
# checking the time series on daily basis

by_day = train.groupby(train.index.dayofyear).mean()
by_day.plot(color = 'red')
plt.title('Analyzing Bitcoin Prices on Daily Basis', fontsize = 20)
plt.ylabel('Prices on Daily Basis')
plt.xlabel('Days')
plt.show()

# %% [markdown]
# ### Analyzing Bitcoin Prices on Day Basis

# %%
# checking the time series on day basis

by_weekday = train.groupby(train.index.dayofweek).sum()
by_weekday.index = ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
by_weekday.plot(color = 'green')
plt.title('Analyzing Bitcoin Prices on Day Basis', fontsize = 20)
plt.ylabel('Prices on Day Basis')
plt.xlabel('Days')
plt.show()

# %% [markdown]
# ### Analyzing Bitcoin Prices on Weekly Basis

# %%
# analyzing data weekly

plt.rcParams['figure.figsize'] = (15, 6)
weekly = train.resample('W').sum()
weekly.plot()
plt.ylabel('Weekly bitcoin price')
plt.title('Analyzing Bitcoin Prices on Weekly Basis', fontsize = 20)
plt.show()

# %% [markdown]
# ### Analyzing Bitcoin Prices on Monthly Basis

# %%
# checking the time series on monthly basis

by_month = train.groupby(train.index.month).mean()
by_month.plot(color = 'grey')
plt.title('Analyzing Bitcoin Prices on Monthly Basis', fontsize = 20)
plt.ylabel('Prices on Monthly Basis')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ### Analyzing Bitcoin Prices on Yearly Basis

# %%
# checking the prices yearly

by_year = train.groupby(train.index.year).mean()
by_year.plot(color = 'black')
plt.title('Analyzing Bitcoin Prices on Yearly Basis', fontsize = 20)
plt.ylabel('Prices on Yearly Basis')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ### Conclusion

# %% [markdown]
# I conclude that we can further predict data based or ARIMA model.
#
# This is how we can predict the prices of the bitcoin which is a cryptocurrency that was invented in 2008.
